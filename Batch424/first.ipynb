# %%
class Employee:
    def __init__(self,name="geeta"):
        self.name = name


emp1  = Employee()

# %%
emp1.name
# Out:
# 'geeta'

# %%
20 to 30 prime numbers
for(20-30)
    prime

# %%
for i in range(4):
    if i==2 :
        continue
    print(i)
# Out:
# 0
# 1
# 3

# %%
for n in range(20,31):
    for i in range(2,n):
        if n%i==0:
            print(n,'is not a prime')
            break
    else:
        print(n,'is prime')

# print("not prime")
# Out:
# 20 is not a prime
# 21 is not a prime
# 22 is not a prime
# 23 is prime
# 24 is not a prime
# 25 is not a prime
# 26 is not a prime
# 27 is not a prime
# 28 is not a prime
# 29 is prime
# 30 is not a prime

# %%
u=[x for x in range(1,16)]

# %%
eu = []
for i in u:
    if not i%2:
        eu.append(i)
print(eu)
# Out:
# [2, 4, 6, 8, 10, 12, 14]
